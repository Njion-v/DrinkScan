# %%
pip install realesrgan opencv-python tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install torchvision==0.15
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from realesrgan import RealESRGANer
import cv2
import os
from tqdm import tqdm

# Initialize the Real-ESRGAN model
model = RealESRGANer(
    scale=4,  # Upscale factor
    model_path='RealESRGAN_x4plus.pth',  # Path to the pre-trained model
    model=None,
    tile=0,  # Tile size (0 for no tiling)
    tile_pad=10,  # Tile padding
    pre_pad=0,  # Pre-padding size
    half=False  # Use half precision (FP16) for faster inference (if supported)
)

def upscale_image(image_path, output_folder, model):
    try:
        # Read the image
        img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
        if img is None:
            print(f"Error reading image: {image_path}")
            return

        # Upscale the image
        output, _ = model.enhance(img, outscale=4)

        # Save the upscaled image
        output_path = os.path.join(output_folder, os.path.basename(image_path))
        cv2.imwrite(output_path, output)
        print(f"Upscaled image saved: {output_path}")

    except Exception as e:
        print(f"Error processing {image_path}: {e}")

def process_folder(input_folder, output_folder, model):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get list of images in the input folder
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

    # Process each image
    for image_file in tqdm(image_files, desc="Upscaling images"):
        image_path = os.path.join(input_folder, image_file)
        upscale_image(image_path, output_folder, model)

if __name__ == "__main__":
    # Define input and output folders
    input_folder = "path/to/low_res_images"  # Replace with your input folder path
    output_folder = "path/to/high_res_images"  # Replace with your output folder path

    # Process all images in the input folder
    process_folder(input_folder, output_folder, model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 from tqdm import tqdm
#       6 # Initialize the Real-ESRGAN model
# ----> 7 model = RealESRGANer(
#       8     scale=4,  # Upscale factor
#       9     model_path='RealESRGAN_x4plus.pth',  # Path to the pre-trained model
#      10     model=None,
#      11     tile=0,  # Tile size (0 for no tiling)
#      12     tile_pad=10,  # Tile padding
#      13     pre_pad=0,  # Pre-padding size
#      14     half=False  # Use half precision (FP16) for faster inference (if supported)
#      15 )
#      17 def upscale_image(image_path, output_folder, model):
#      18     try:
#      19         # Read the image
#
# ...
